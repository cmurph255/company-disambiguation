# %%
import pandas as pd
import itertools
import random

# %%
random.seed(42)  # make it reproducible, remove if you want true randomness

prefixes = [
    "AAF","Aegon","Aequim","AllianceBernstein","Amiral","Analog","Arrowpoint","Asia",
    "Aspen","Aspire","Assetmark","Athora","Banca","Bigelow","Birch","Black","Bontempo",
    # "Booster","Calton","Cutler","Daintree","Dana","Davidson","DWS","Eagle","Earnest",
    # "East","EBA","Elmwood","Giant","Gitterman","GKFO","Gladstone","IAMS","ICICI","IFG",
    # "IHT","Illinois","Janus","Jefferson","Jennison","LBMC","Lombard","Longview",
    # "MerQube","Merriman","Mesirow","Newman","Obrinvest","OCBC","Paulson","PAX","Petra",
    "Pin","Pine","Prudent","PUTNAM","Qtrade","Rockwood","Safeguard","Sittner","Tavira",
    "TCFG","TCI","Tradewinds","University","Usmart"
]

suffixes = [
    "Collective Investment",    "Collective Trust",    "Collective Services",    "Wealth Management",    "Wealth Advisors",
    "Wealth Partners",    "Wealth Group",    "Capital Management",    "Capital Group",    "Capital Partners",
    "Capital Advisors",    "Capital",    "Financial",    "Financial Advisors",    "Financial Partners",
    "Financial Trust",    "Investment Management",    "Investment Company",    "Investment Partners",
    "Advisory",    "Advisory Group",    "Advisory Services",    "Asset Management",
    "Asset Management Group",    "Asset Management Partners"
]

def build_name(prefix, suffix):
    return f"{prefix} {suffix}".strip()

rows = []

# 1. HARD NEGATIVES (different prefix, SAME suffix)
# score ~ [0.02, 0.08]
for sfx in suffixes:
    # all variants with this suffix
    names_for_suffix = [build_name(p, sfx) for p in prefixes]

    # choose all unique pairs of DIFFERENT prefixes but SAME suffix
    for i in range(len(prefixes)):
        for j in range(i + 1, len(prefixes)):
            a = build_name(prefixes[i], sfx)
            b = build_name(prefixes[j], sfx)
            sim_score = random.uniform(0.02, 0.08)
            rows.append({
                "sentence1": a,
                "sentence2": b,
                "similarity": round(sim_score, 3)
            })

random.shuffle(rows)
rows = rows[:400]

# 2. MEDIUM NEGATIVES (different prefix, DIFFERENT suffix)
# score ~ [0.18, 0.32]
# this can explode combinatorially, so we'll just sample some combos
all_generated = [(p, s, build_name(p, s)) for p in prefixes for s in suffixes]
all_pairs = list(itertools.combinations(all_generated, 2))
random.shuffle(all_pairs)

for (p1, s1, name1), (p2, s2, name2) in all_pairs[:200]:
    if p1 != p2 and s1 != s2:
        sim_score = random.uniform(0.12, 0.22)
        rows.append({
            "sentence1": name1,
            "sentence2": name2,
            "similarity": round(sim_score, 3)
        })


rows2 = []
# 3. RELATED BUT NOT IDENTICAL (same prefix, DIFFERENT suffix)
# keep this stable ~0.6 so the model learns this tier as a "close, but not same"
for p in prefixes:
    for sfx_a, sfx_b in itertools.combinations(suffixes, 2):
        a = build_name(p, sfx_a)
        b = build_name(p, sfx_b)
        rows2.append({
            "sentence1": a,
            "sentence2": b,
            "similarity": 0.6
        })
        
random.shuffle(rows2)
rows2 = rows2[:200]
rows += rows2

df = pd.DataFrame(rows, columns=["sentence1", "sentence2", "similarity"])

# %%
df
# Out:
#                         sentence1                          sentence2  \
# 0                Aspire Financial                   PUTNAM Financial
# 1    Assetmark Financial Partners      Tradewinds Financial Partners
# 2        Bigelow Asset Management               TCI Asset Management
# 3             Pin Wealth Partners          Safeguard Wealth Partners
# 4          Qtrade Wealth Partners             Usmart Wealth Partners
# ..                            ...                                ...
# 782    University Financial Trust  University Asset Management Group
# 783  Safeguard Capital Management           Safeguard Advisory Group
# 784        Tavira Financial Trust                    Tavira Advisory
# 785        Analog Financial Trust          Analog Investment Company
# 786         Pine Capital Advisors                     Pine Financial
#
#      similarity
# 0         0.059
# 1         0.079
# 2         0.063
# 3         0.051
# 4         0.073
# ..          ...
# 782       0.600
# 783       0.600
# 784       0.600
# 785       0.600
# 786       0.600
#
# [787 rows x 3 columns]

# %%
df.to_csv("training-data.csv", index=False, encoding="utf-8-sig")

# %%
rows2
# Out:
# [{'sentence1': 'Aspire Wealth Group',
#   'sentence2': 'Aspire Investment Partners',
#   'similarity': 0.6},
#  {'sentence1': 'University Capital Management',
#   'sentence2': 'University Financial Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Pin Wealth Partners',
#   'sentence2': 'Pin Advisory',
#   'similarity': 0.6},
#  {'sentence1': 'Rockwood Capital',
#   'sentence2': 'Rockwood Financial Advisors',
#   'similarity': 0.6},
#  {'sentence1': 'Pine Capital Partners',
#   'sentence2': 'Pine Capital Advisors',
#   'similarity': 0.6},
#  {'sentence1': 'Birch Investment Partners',
#   'sentence2': 'Birch Advisory Services',
#   'similarity': 0.6},
#  {'sentence1': 'Tavira Collective Trust',
#   'sentence2': 'Tavira Capital Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Analog Collective Services',
#   'sentence2': 'Analog Capital Group',
#   'similarity': 0.6},
#  {'sentence1': 'Pin Collective Investment',
#   'sentence2': 'Pin Collective Services',
#   'similarity': 0.6},
#  {'sentence1': 'Tradewinds Capital Management',
#   'sentence2': 'Tradewinds Capital',
#   'similarity': 0.6},
#  {'sentence1': 'AAF Collective Services',
#   'sentence2': 'AAF Investment Management',
#   'similarity': 0.6},
#  {'sentence1': 'Rockwood Wealth Group',
#   'sentence2': 'Rockwood Capital',
#   'similarity': 0.6},
#  {'sentence1': 'TCFG Collective Services',
#   'sentence2': 'TCFG Capital Group',
#   'similarity': 0.6},
#  {'sentence1': 'TCI Capital Group',
#   'sentence2': 'TCI Investment Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Aspire Financial Partners',
#   'sentence2': 'Aspire Advisory Services',
#   'similarity': 0.6},
#  {'sentence1': 'Bontempo Capital Advisors',
#   'sentence2': 'Bontempo Financial Advisors',
#   'similarity': 0.6},
#  {'sentence1': 'Prudent Capital Management',
#   'sentence2': 'Prudent Asset Management Group',
#   'similarity': 0.6},
#  {'sentence1': 'Prudent Capital',
#   'sentence2': 'Prudent Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Tavira Collective Services',
#   'sentence2': 'Tavira Investment Management',
#   'similarity': 0.6},
#  {'sentence1': 'AAF Financial',
#   'sentence2': 'AAF Asset Management Group',
#   'similarity': 0.6},
#  {'sentence1': 'Asia Wealth Management',
#   'sentence2': 'Asia Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Banca Capital',
#   'sentence2': 'Banca Asset Management Group',
#   'similarity': 0.6},
#  {'sentence1': 'Rockwood Collective Investment',
#   'sentence2': 'Rockwood Asset Management Group',
#   'similarity': 0.6},
#  {'sentence1': 'Asia Capital Management',
#   'sentence2': 'Asia Investment Management',
#   'similarity': 0.6},
#  {'sentence1': 'TCFG Collective Investment',
#   'sentence2': 'TCFG Capital Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Black Capital Group',
#   'sentence2': 'Black Advisory',
#   'similarity': 0.6},
#  {'sentence1': 'University Capital',
#   'sentence2': 'University Asset Management Group',
#   'similarity': 0.6},
#  {'sentence1': 'Tradewinds Wealth Group',
#   'sentence2': 'Tradewinds Financial',
#   'similarity': 0.6},
#  {'sentence1': 'Analog Collective Services',
#   'sentence2': 'Analog Wealth Group',
#   'similarity': 0.6},
#  {'sentence1': 'Athora Capital Group',
#   'sentence2': 'Athora Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Analog Advisory Services',
#   'sentence2': 'Analog Asset Management',
#   'similarity': 0.6},
#  {'sentence1': 'Safeguard Capital Partners',
#   'sentence2': 'Safeguard Asset Management Group',
#   'similarity': 0.6},
#  {'sentence1': 'AAF Financial Trust',
#   'sentence2': 'AAF Investment Company',
#   'similarity': 0.6},
#  {'sentence1': 'Tavira Capital',
#   'sentence2': 'Tavira Investment Management',
#   'similarity': 0.6},
#  {'sentence1': 'Safeguard Advisory',
#   'sentence2': 'Safeguard Advisory Group',
#   'similarity': 0.6},
#  {'sentence1': 'Aequim Financial Partners',
#   'sentence2': 'Aequim Advisory Group',
#   'similarity': 0.6},
#  {'sentence1': 'Assetmark Wealth Management',
#   'sentence2': 'Assetmark Capital Group',
#   'similarity': 0.6},
#  {'sentence1': 'TCFG Collective Services',
#   'sentence2': 'TCFG Investment Management',
#   'similarity': 0.6},
#  {'sentence1': 'University Wealth Management',
#   'sentence2': 'University Financial Trust',
#   'similarity': 0.6},
#  {'sentence1': 'Usmart Collective Investment',
#   'sentence2': 'Usmart Asset Management',
#   'similarity': 0.6},
#  {'sentence1': 'Birch Collective Investment',
#   'sentence2': 'Birch Collective Trust',
#   'similarity': 0.6},
#  {'sentence1': 'TCFG Investment Partners',
#   'sentence2': 'TCFG Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'University Capital Management',
#   'sentence2': 'University Financial',
#   'similarity': 0.6},
#  {'sentence1': 'Asia Collective Investment',
#   'sentence2': 'Asia Collective Trust',
#   'similarity': 0.6},
#  {'sentence1': 'TCFG Financial Partners',
#   'sentence2': 'TCFG Advisory Group',
#   'similarity': 0.6},
#  {'sentence1': 'TCI Capital Partners',
#   'sentence2': 'TCI Advisory',
#   'similarity': 0.6},
#  {'sentence1': 'Tavira Capital',
#   'sentence2': 'Tavira Investment Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Black Capital Management',
#   'sentence2': 'Black Capital Group',
#   'similarity': 0.6},
#  {'sentence1': 'Birch Collective Services',
#   'sentence2': 'Birch Investment Management',
#   'similarity': 0.6},
#  {'sentence1': 'Bontempo Collective Services',
#   'sentence2': 'Bontempo Capital Advisors',
#   'similarity': 0.6},
#  {'sentence1': 'Aspen Wealth Advisors',
#   'sentence2': 'Aspen Advisory Services',
#   'similarity': 0.6},
#  {'sentence1': 'Bigelow Financial Advisors',
#   'sentence2': 'Bigelow Financial Partners',
#   'similarity': 0.6},
#  {'sentence1': 'PUTNAM Capital Group',
#   'sentence2': 'PUTNAM Investment Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Aegon Collective Services',
#   'sentence2': 'Aegon Wealth Group',
#   'similarity': 0.6},
#  {'sentence1': 'Pin Capital',
#   'sentence2': 'Pin Investment Management',
#   'similarity': 0.6},
#  {'sentence1': 'Aegon Wealth Management',
#   'sentence2': 'Aegon Wealth Group',
#   'similarity': 0.6},
#  {'sentence1': 'Prudent Collective Investment',
#   'sentence2': 'Prudent Collective Services',
#   'similarity': 0.6},
#  {'sentence1': 'Bontempo Capital Group',
#   'sentence2': 'Bontempo Advisory Services',
#   'similarity': 0.6},
#  {'sentence1': 'Sittner Collective Investment',
#   'sentence2': 'Sittner Collective Services',
#   'similarity': 0.6},
#  {'sentence1': 'Bontempo Wealth Partners',
#   'sentence2': 'Bontempo Advisory Group',
#   'similarity': 0.6},
#  {'sentence1': 'AllianceBernstein Financial Partners',
#   'sentence2': 'AllianceBernstein Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Pin Advisory',
#   'sentence2': 'Pin Asset Management',
#   'similarity': 0.6},
#  {'sentence1': 'University Asset Management',
#   'sentence2': 'University Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'AAF Wealth Advisors',
#   'sentence2': 'AAF Wealth Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Usmart Collective Services',
#   'sentence2': 'Usmart Asset Management',
#   'similarity': 0.6},
#  {'sentence1': 'Pine Financial',
#   'sentence2': 'Pine Investment Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Pin Capital Group',
#   'sentence2': 'Pin Financial Trust',
#   'similarity': 0.6},
#  {'sentence1': 'Sittner Financial Advisors',
#   'sentence2': 'Sittner Asset Management Group',
#   'similarity': 0.6},
#  {'sentence1': 'Tavira Collective Trust',
#   'sentence2': 'Tavira Capital Group',
#   'similarity': 0.6},
#  {'sentence1': 'Pine Investment Company',
#   'sentence2': 'Pine Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Pin Capital',
#   'sentence2': 'Pin Investment Partners',
#   'similarity': 0.6},
#  {'sentence1': 'TCFG Wealth Management',
#   'sentence2': 'TCFG Advisory',
#   'similarity': 0.6},
#  {'sentence1': 'Analog Capital',
#   'sentence2': 'Analog Advisory Services',
#   'similarity': 0.6},
#  {'sentence1': 'University Collective Trust',
#   'sentence2': 'University Capital Management',
#   'similarity': 0.6},
#  {'sentence1': 'Aequim Investment Management',
#   'sentence2': 'Aequim Investment Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Bigelow Collective Trust',
#   'sentence2': 'Bigelow Wealth Management',
#   'similarity': 0.6},
#  {'sentence1': 'Asia Capital Management',
#   'sentence2': 'Asia Financial Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Sittner Investment Partners',
#   'sentence2': 'Sittner Asset Management',
#   'similarity': 0.6},
#  {'sentence1': 'Prudent Wealth Partners',
#   'sentence2': 'Prudent Capital Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Tradewinds Capital Partners',
#   'sentence2': 'Tradewinds Financial',
#   'similarity': 0.6},
#  {'sentence1': 'Aspen Investment Partners',
#   'sentence2': 'Aspen Advisory',
#   'similarity': 0.6},
#  {'sentence1': 'Amiral Collective Services',
#   'sentence2': 'Amiral Capital',
#   'similarity': 0.6},
#  {'sentence1': 'Tavira Wealth Advisors',
#   'sentence2': 'Tavira Financial Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Prudent Capital Management',
#   'sentence2': 'Prudent Asset Management',
#   'similarity': 0.6},
#  {'sentence1': 'University Financial',
#   'sentence2': 'University Financial Trust',
#   'similarity': 0.6},
#  {'sentence1': 'Bigelow Wealth Management',
#   'sentence2': 'Bigelow Investment Management',
#   'similarity': 0.6},
#  {'sentence1': 'Tavira Collective Services',
#   'sentence2': 'Tavira Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Prudent Capital Partners',
#   'sentence2': 'Prudent Financial Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Rockwood Financial Trust',
#   'sentence2': 'Rockwood Advisory',
#   'similarity': 0.6},
#  {'sentence1': 'TCI Wealth Partners',
#   'sentence2': 'TCI Investment Company',
#   'similarity': 0.6},
#  {'sentence1': 'Bigelow Collective Investment',
#   'sentence2': 'Bigelow Investment Management',
#   'similarity': 0.6},
#  {'sentence1': 'Pin Capital Management',
#   'sentence2': 'Pin Financial',
#   'similarity': 0.6},
#  {'sentence1': 'Assetmark Collective Services',
#   'sentence2': 'Assetmark Investment Management',
#   'similarity': 0.6},
#  {'sentence1': 'Amiral Wealth Advisors',
#   'sentence2': 'Amiral Wealth Partners',
#   'similarity': 0.6},
#  {'sentence1': 'AllianceBernstein Wealth Advisors',
#   'sentence2': 'AllianceBernstein Capital',
#   'similarity': 0.6},
#  {'sentence1': 'Birch Financial Advisors',
#   'sentence2': 'Birch Asset Management Group',
#   'similarity': 0.6},
#  {'sentence1': 'Rockwood Capital Partners',
#   'sentence2': 'Rockwood Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Analog Collective Services',
#   'sentence2': 'Analog Advisory Services',
#   'similarity': 0.6},
#  {'sentence1': 'Tavira Wealth Partners',
#   'sentence2': 'Tavira Financial Trust',
#   'similarity': 0.6},
#  {'sentence1': 'Athora Wealth Partners',
#   'sentence2': 'Athora Financial Advisors',
#   'similarity': 0.6},
#  {'sentence1': 'Amiral Capital Management',
#   'sentence2': 'Amiral Financial Partners',
#   'similarity': 0.6},
#  {'sentence1': 'TCFG Collective Trust',
#   'sentence2': 'TCFG Investment Management',
#   'similarity': 0.6},
#  {'sentence1': 'Birch Capital Management',
#   'sentence2': 'Birch Advisory Group',
#   'similarity': 0.6},
#  {'sentence1': 'TCFG Capital Management',
#   'sentence2': 'TCFG Financial Trust',
#   'similarity': 0.6},
#  {'sentence1': 'TCFG Financial Partners',
#   'sentence2': 'TCFG Asset Management',
#   'similarity': 0.6},
#  {'sentence1': 'Athora Investment Company',
#   'sentence2': 'Athora Advisory',
#   'similarity': 0.6},
#  {'sentence1': 'Tavira Collective Trust',
#   'sentence2': 'Tavira Financial Trust',
#   'similarity': 0.6},
#  {'sentence1': 'Banca Advisory Services',
#   'sentence2': 'Banca Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Assetmark Advisory',
#   'sentence2': 'Assetmark Advisory Services',
#   'similarity': 0.6},
#  {'sentence1': 'Sittner Financial Advisors',
#   'sentence2': 'Sittner Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Pine Financial',
#   'sentence2': 'Pine Financial Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Analog Capital',
#   'sentence2': 'Analog Advisory',
#   'similarity': 0.6},
#  {'sentence1': 'Aspen Investment Company',
#   'sentence2': 'Aspen Asset Management',
#   'similarity': 0.6},
#  {'sentence1': 'Pine Investment Partners',
#   'sentence2': 'Pine Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Tradewinds Capital Advisors',
#   'sentence2': 'Tradewinds Financial',
#   'similarity': 0.6},
#  {'sentence1': 'Tavira Wealth Partners',
#   'sentence2': 'Tavira Wealth Group',
#   'similarity': 0.6},
#  {'sentence1': 'Safeguard Capital Advisors',
#   'sentence2': 'Safeguard Financial',
#   'similarity': 0.6},
#  {'sentence1': 'Amiral Collective Investment',
#   'sentence2': 'Amiral Capital Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Amiral Investment Management',
#   'sentence2': 'Amiral Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Black Wealth Group',
#   'sentence2': 'Black Capital Management',
#   'similarity': 0.6},
#  {'sentence1': 'Bontempo Collective Trust',
#   'sentence2': 'Bontempo Financial Advisors',
#   'similarity': 0.6},
#  {'sentence1': 'Pine Wealth Management',
#   'sentence2': 'Pine Financial Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Birch Capital Management',
#   'sentence2': 'Birch Investment Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Tavira Wealth Management',
#   'sentence2': 'Tavira Wealth Partners',
#   'similarity': 0.6},
#  {'sentence1': 'TCI Capital Advisors',
#   'sentence2': 'TCI Advisory Services',
#   'similarity': 0.6},
#  {'sentence1': 'Safeguard Wealth Management',
#   'sentence2': 'Safeguard Financial',
#   'similarity': 0.6},
#  {'sentence1': 'Prudent Wealth Management',
#   'sentence2': 'Prudent Investment Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Birch Capital Advisors',
#   'sentence2': 'Birch Financial Trust',
#   'similarity': 0.6},
#  {'sentence1': 'TCFG Wealth Management',
#   'sentence2': 'TCFG Wealth Advisors',
#   'similarity': 0.6},
#  {'sentence1': 'Aspen Wealth Advisors',
#   'sentence2': 'Aspen Financial Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Bontempo Capital Advisors',
#   'sentence2': 'Bontempo Financial Trust',
#   'similarity': 0.6},
#  {'sentence1': 'Safeguard Collective Services',
#   'sentence2': 'Safeguard Advisory Group',
#   'similarity': 0.6},
#  {'sentence1': 'AAF Financial Partners',
#   'sentence2': 'AAF Financial Trust',
#   'similarity': 0.6},
#  {'sentence1': 'Aequim Capital Management',
#   'sentence2': 'Aequim Advisory Group',
#   'similarity': 0.6},
#  {'sentence1': 'Asia Financial Trust',
#   'sentence2': 'Asia Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'TCI Collective Trust',
#   'sentence2': 'TCI Financial Advisors',
#   'similarity': 0.6},
#  {'sentence1': 'Tradewinds Collective Investment',
#   'sentence2': 'Tradewinds Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'PUTNAM Wealth Group',
#   'sentence2': 'PUTNAM Financial',
#   'similarity': 0.6},
#  {'sentence1': 'Rockwood Capital Partners',
#   'sentence2': 'Rockwood Investment Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Aspire Capital Advisors',
#   'sentence2': 'Aspire Financial Trust',
#   'similarity': 0.6},
#  {'sentence1': 'Safeguard Collective Trust',
#   'sentence2': 'Safeguard Collective Services',
#   'similarity': 0.6},
#  {'sentence1': 'AllianceBernstein Wealth Partners',
#   'sentence2': 'AllianceBernstein Financial Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Analog Capital Group',
#   'sentence2': 'Analog Capital Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Birch Capital Advisors',
#   'sentence2': 'Birch Capital',
#   'similarity': 0.6},
#  {'sentence1': 'Arrowpoint Financial Partners',
#   'sentence2': 'Arrowpoint Investment Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Sittner Financial Advisors',
#   'sentence2': 'Sittner Investment Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Tavira Capital Advisors',
#   'sentence2': 'Tavira Financial',
#   'similarity': 0.6},
#  {'sentence1': 'Qtrade Collective Trust',
#   'sentence2': 'Qtrade Capital Group',
#   'similarity': 0.6},
#  {'sentence1': 'Tradewinds Capital',
#   'sentence2': 'Tradewinds Financial Trust',
#   'similarity': 0.6},
#  {'sentence1': 'AllianceBernstein Asset Management Group',
#   'sentence2': 'AllianceBernstein Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'AAF Wealth Advisors',
#   'sentence2': 'AAF Capital Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Black Collective Investment',
#   'sentence2': 'Black Asset Management Group',
#   'similarity': 0.6},
#  {'sentence1': 'Bontempo Financial Trust',
#   'sentence2': 'Bontempo Investment Management',
#   'similarity': 0.6},
#  {'sentence1': 'Qtrade Financial Partners',
#   'sentence2': 'Qtrade Investment Company',
#   'similarity': 0.6},
#  {'sentence1': 'Assetmark Capital',
#   'sentence2': 'Assetmark Financial Advisors',
#   'similarity': 0.6},
#  {'sentence1': 'Safeguard Wealth Group',
#   'sentence2': 'Safeguard Financial',
#   'similarity': 0.6},
#  {'sentence1': 'Safeguard Capital Advisors',
#   'sentence2': 'Safeguard Financial Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Aspire Collective Investment',
#   'sentence2': 'Aspire Capital Advisors',
#   'similarity': 0.6},
#  {'sentence1': 'Asia Advisory Services',
#   'sentence2': 'Asia Asset Management',
#   'similarity': 0.6},
#  {'sentence1': 'TCI Collective Investment',
#   'sentence2': 'TCI Financial Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Pine Capital Advisors',
#   'sentence2': 'Pine Financial Advisors',
#   'similarity': 0.6},
#  {'sentence1': 'University Collective Trust',
#   'sentence2': 'University Investment Management',
#   'similarity': 0.6},
#  {'sentence1': 'Banca Collective Trust',
#   'sentence2': 'Banca Investment Management',
#   'similarity': 0.6},
#  {'sentence1': 'Tavira Capital Advisors',
#   'sentence2': 'Tavira Financial Advisors',
#   'similarity': 0.6},
#  {'sentence1': 'Aegon Collective Investment',
#   'sentence2': 'Aegon Advisory Services',
#   'similarity': 0.6},
#  {'sentence1': 'Amiral Capital Partners',
#   'sentence2': 'Amiral Investment Company',
#   'similarity': 0.6},
#  {'sentence1': 'Birch Capital Partners',
#   'sentence2': 'Birch Advisory',
#   'similarity': 0.6},
#  {'sentence1': 'Amiral Wealth Partners',
#   'sentence2': 'Amiral Asset Management Group',
#   'similarity': 0.6},
#  {'sentence1': 'TCFG Collective Services',
#   'sentence2': 'TCFG Financial Trust',
#   'similarity': 0.6},
#  {'sentence1': 'Qtrade Wealth Group',
#   'sentence2': 'Qtrade Financial Advisors',
#   'similarity': 0.6},
#  {'sentence1': 'Prudent Collective Investment',
#   'sentence2': 'Prudent Capital',
#   'similarity': 0.6},
#  {'sentence1': 'TCI Wealth Partners',
#   'sentence2': 'TCI Capital Management',
#   'similarity': 0.6},
#  {'sentence1': 'Safeguard Investment Company',
#   'sentence2': 'Safeguard Investment Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Tradewinds Collective Services',
#   'sentence2': 'Tradewinds Wealth Advisors',
#   'similarity': 0.6},
#  {'sentence1': 'Aspen Capital',
#   'sentence2': 'Aspen Financial Advisors',
#   'similarity': 0.6},
#  {'sentence1': 'Athora Capital Partners',
#   'sentence2': 'Athora Asset Management Group',
#   'similarity': 0.6},
#  {'sentence1': 'Prudent Capital Partners',
#   'sentence2': 'Prudent Financial Advisors',
#   'similarity': 0.6},
#  {'sentence1': 'Bigelow Investment Company',
#   'sentence2': 'Bigelow Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Pin Collective Trust',
#   'sentence2': 'Pin Capital Group',
#   'similarity': 0.6},
#  {'sentence1': 'Rockwood Investment Partners',
#   'sentence2': 'Rockwood Advisory Services',
#   'similarity': 0.6},
#  {'sentence1': 'Arrowpoint Collective Services',
#   'sentence2': 'Arrowpoint Asset Management Group',
#   'similarity': 0.6},
#  {'sentence1': 'Bigelow Financial',
#   'sentence2': 'Bigelow Investment Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Rockwood Wealth Advisors',
#   'sentence2': 'Rockwood Wealth Partners',
#   'similarity': 0.6},
#  {'sentence1': 'Pine Investment Company',
#   'sentence2': 'Pine Asset Management Group',
#   'similarity': 0.6},
#  {'sentence1': 'TCI Collective Investment',
#   'sentence2': 'TCI Financial',
#   'similarity': 0.6},
#  {'sentence1': 'Rockwood Investment Management',
#   'sentence2': 'Rockwood Advisory Services',
#   'similarity': 0.6},
#  {'sentence1': 'Analog Wealth Management',
#   'sentence2': 'Analog Advisory Group',
#   'similarity': 0.6},
#  {'sentence1': 'Tavira Wealth Management',
#   'sentence2': 'Tavira Advisory Services',
#   'similarity': 0.6},
#  {'sentence1': 'Tavira Investment Partners',
#   'sentence2': 'Tavira Advisory Group',
#   'similarity': 0.6},
#  {'sentence1': 'Usmart Collective Trust',
#   'sentence2': 'Usmart Investment Company',
#   'similarity': 0.6},
#  {'sentence1': 'PUTNAM Wealth Advisors',
#   'sentence2': 'PUTNAM Capital Advisors',
#   'similarity': 0.6},
#  {'sentence1': 'Sittner Financial',
#   'sentence2': 'Sittner Advisory Services',
#   'similarity': 0.6},
#  {'sentence1': 'Analog Wealth Management',
#   'sentence2': 'Analog Capital Management',
#   'similarity': 0.6},
#  {'sentence1': 'Usmart Wealth Partners',
#   'sentence2': 'Usmart Advisory Group',
#   'similarity': 0.6},
#  {'sentence1': 'Aspen Investment Company',
#   'sentence2': 'Aspen Asset Management Partners',
#   'similarity': 0.6},
#  {'sentence1': 'University Financial Trust',
#   'sentence2': 'University Asset Management Group',
#   'similarity': 0.6},
#  {'sentence1': 'Safeguard Capital Management',
#   'sentence2': 'Safeguard Advisory Group',
#   'similarity': 0.6},
#  {'sentence1': 'Tavira Financial Trust',
#   'sentence2': 'Tavira Advisory',
#   'similarity': 0.6},
#  {'sentence1': 'Analog Financial Trust',
#   'sentence2': 'Analog Investment Company',
#   'similarity': 0.6},
#  {'sentence1': 'Pine Capital Advisors',
#   'sentence2': 'Pine Financial',
#   'similarity': 0.6}]
